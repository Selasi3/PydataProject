# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("csv/timeseries.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    501 non-null    object
#  1   country                                 501 non-null    object
#  2   state                                   501 non-null    object
#  3   county                                  0 non-null      float64
#  4   fips                                    501 non-null    int64
#  5   lat                                     0 non-null      float64
#  6   long                                    0 non-null      float64
#  7   locationId                              501 non-null    object
#  8   actuals.cases                           492 non-null    float64
#  9   actuals.deaths                          492 non-null    float64
# ...

# %%
data.describe(include="object")
# Out:
#               date country state          locationId actuals.contactTracers  \
# count          501     501   501                 501                    501
# unique         481       1     1                   1                      8
# top     2020-10-04      US    PA  iso1:us#iso2:us-pa                   1508
# freq             2     501   501                 501                    285
#
#        actuals.icuBeds.currentUsageCovid
# count                                495
# unique                               260
# top                        Not Available
# freq                                 193

# %%
data.describe()
# Out:
#        county   fips  lat  long  actuals.cases  actuals.deaths  \
# count     0.0  501.0  0.0   0.0   4.920000e+02      492.000000
# mean      NaN   42.0  NaN   NaN   4.610324e+05    12899.796748
# std       NaN    0.0  NaN   NaN   4.402533e+05     9208.187981
# min       NaN   42.0  NaN   NaN   2.000000e+00        0.000000
# 25%       NaN   42.0  NaN   NaN   9.170450e+04     6701.750000
# 50%       NaN   42.0  NaN   NaN   1.923740e+05     8644.500000
# 75%       NaN   42.0  NaN   NaN   9.186368e+05    23644.250000
# max       NaN   42.0  NaN   NaN   1.215735e+06    27675.000000
#
#        actuals.positiveTests  actuals.negativeTests  \
# count           4.960000e+02           4.980000e+02
# mean            4.984688e+05           5.395527e+06
# std             4.503788e+05           4.734033e+06
# min             1.000000e+00           9.000000e+00
# 25%             1.169840e+05           8.947250e+05
# 50%             2.400670e+05           3.855450e+06
# ...

# %%
data.head()
# Out:
#          date country state  county  fips  lat  long          locationId  \
# 0  2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 1  2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2  2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 3  2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 4  2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#    actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# 0            NaN             NaN  ...                    NaN
# 1            NaN             NaN  ...                    NaN
# 2            NaN             NaN  ...                    NaN
# 3            NaN             NaN  ...                    NaN
# 4            2.0             0.0  ...                    NaN
#
#    metrics.infectionRateCI90 metrics.icuHeadroomRatio  \
# 0                        NaN                      NaN
# ...

# %%
data.duplicated().sum()
# Out:
# 20

# %% [markdown]
# The dataset comprises of 39 columns and 501 rows of data of which the sum of duplicated rows are 20.

# %%
data["date"] = pd.to_datetime(data["date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    501 non-null    datetime64[ns]
#  1   country                                 501 non-null    object
#  2   state                                   501 non-null    object
#  3   county                                  0 non-null      float64
#  4   fips                                    501 non-null    int64
#  5   lat                                     0 non-null      float64
#  6   long                                    0 non-null      float64
#  7   locationId                              501 non-null    object
#  8   actuals.cases                           492 non-null    float64
#  9   actuals.deaths                          492 non-null    float64
# ...

# %%
data.head()
# Out:
#         date country state  county  fips  lat  long          locationId  \
# 0 2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 1 2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2 2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 3 2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 4 2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#    actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# 0            NaN             NaN  ...                    NaN
# 1            NaN             NaN  ...                    NaN
# 2            NaN             NaN  ...                    NaN
# 3            NaN             NaN  ...                    NaN
# 4            2.0             0.0  ...                    NaN
#
#    metrics.infectionRateCI90 metrics.icuHeadroomRatio  \
# 0                        NaN                      NaN
# ...

# %%
data["state"].nunique()
# Out:
# 1

# %%
data.set_index("date",inplace=True)

# %%
data.head()
# Out:
#            country state  county  fips  lat  long          locationId  \
# date
# 2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#             actuals.cases  actuals.deaths  actuals.positiveTests  ...  \
# date                                                              ...
# 2020-03-02            NaN             NaN                    NaN  ...
# 2020-03-03            NaN             NaN                    1.0  ...
# 2020-03-04            NaN             NaN                    1.0  ...
# 2020-03-05            NaN             NaN                    2.0  ...
# 2020-03-06            2.0             0.0                    7.0  ...
#
# ...

# %%
june_16_21 =data.loc["2021-06-16"]

# %%
june_16_21
# Out:
#            country state  county  fips  lat  long          locationId  \
# date
# 2021-06-16      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#             actuals.cases  actuals.deaths  actuals.positiveTests  ...  \
# date                                                              ...
# 2021-06-16      1214051.0         27582.0              1246387.0  ...
#
#             metrics.infectionRate metrics.infectionRateCI90  \
# date
# 2021-06-16                    0.7                       0.1
#
#             metrics.icuHeadroomRatio  metrics.icuHeadroomDetails  \
# date
# 2021-06-16                       0.1                         NaN
#
#             metrics.icuCapacityRatio  riskLevels.overall  \
# date
# 2021-06-16                      0.73                   1
#
#             metrics.vaccinationsInitiatedRatio  \
# date
# 2021-06-16                               0.611
#
#             metrics.vaccinationsCompletedRatio actuals.newDeaths  \
# date
# ...

# %%
june_16_21["state"][0]
# Out:
# 'PA'

# %%
june_16_21["actuals.newDeaths"][0]
# Out:
# 16.0

# %%
june_16_21["actuals.newCases"][0]
# Out:
# 279.0

# %%
june_16_21["actuals.cases"][0]
# Out:
# 1214051.0

# %%
june_16_21["actuals.deaths"][0]
# Out:
# 27582.0

# %%
june_16_21["metrics.vaccinationsInitiatedRatio"][0]
# Out:
# 0.611

# %%
june_16_21["metrics.vaccinationsCompletedRatio"]
# Out:
# date
# 2021-06-16    0.472
# Name: metrics.vaccinationsCompletedRatio, dtype: float64

# %%
data_values = {
    "state": june_16_21["state"][0],
    "New Death": june_16_21["actuals.newDeaths"][0],
    "New Cases": june_16_21["actuals.newCases"][0],
    "Cummulative Cases" : june_16_21["actuals.cases"][0],
    "Cummulative Death": june_16_21["actuals.deaths"][0],
    "Initiated Vaccination Ratio": june_16_21["metrics.vaccinationsInitiatedRatio"][0],
    "Completed Vaccination Ratio":june_16_21["metrics.vaccinationsCompletedRatio"][0]
}

# %%
data_values
# Out:
# {'state': 'PA',
#  'New Death': 16.0,
#  'New Cases': 279.0,
#  'Cummulative Cases': 1214051.0,
#  'Cummulative Death': 27582.0,
#  'Initiated Vaccination Ratio': 0.611,
#  'Completed Vaccination Ratio': 0.472}

# %%
sns.lineplot(data=data, x="actuals.cases",y='metrics.vaccinationsCompletedRatio')
# Out:
# <AxesSubplot:xlabel='actuals.cases', ylabel='metrics.vaccinationsCompletedRatio'>
